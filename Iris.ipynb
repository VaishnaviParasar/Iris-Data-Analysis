# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishnaviParasar/Iris-Data-Analysis/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
iris = pd.read_csv( 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header = None, names = ['sl','sw','pl','pw','spices'] )

# %%
df = iris.copy()

# %%
df.head(5)
# Out:
#     sl   sw   pl   pw       spices
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.sl
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sl, Length: 150, dtype: float64

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw  spices
# 0    False  False  False  False   False
# 1    False  False  False  False   False
# 2    False  False  False  False   False
# 3    False  False  False  False   False
# 4    False  False  False  False   False
# ..     ...    ...    ...    ...     ...
# 145  False  False  False  False   False
# 146  False  False  False  False   False
# 147  False  False  False  False   False
# 148  False  False  False  False   False
# 149  False  False  False  False   False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sl        0
# sw        0
# pl        0
# pw        0
# spices    0
# dtype: int64

# %%
df.iloc[1:3,2:4]
# Out:
#     pl   pw
# 1  1.4  0.2
# 2  1.3  0.2

# %%
df['sl'].sum()
# Out:
# 876.5

# %%
df[(df.sl > 7) & (df.pl >6.5)]
# Out:
#       sl   sw   pl   pw          spices
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 122  7.7  2.8  6.7  2.0  Iris-virginica

# %%
df.groupby('spices').agg(['mean','max','min']).round(2)
# Out:
#                    sl              sw              pl              pw       \
#                  mean  max  min  mean  max  min  mean  max  min  mean  max
# spices
# Iris-setosa      5.01  5.8  4.3  3.42  4.4  2.3  1.46  1.9  1.0  0.24  0.6
# Iris-versicolor  5.94  7.0  4.9  2.77  3.4  2.0  4.26  5.1  3.0  1.33  1.8
# Iris-virginica   6.59  7.9  4.9  2.97  3.8  2.2  5.55  6.9  4.5  2.03  2.5
#
#
#                  min
# spices
# Iris-setosa      0.1
# Iris-versicolor  1.0
# Iris-virginica   1.4

# %%
df=iris

# %%
df.drop(df.index[0],inplace=True)

# %%
df=iris

# %%
df
# Out:
#       sl   sw   pl   pw          spices
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['sum']=df['sl']+df['sw']

# %%
df
# Out:
#       sl   sw   pl   pw          spices  sum
# 0    5.1  3.5  1.4  0.2     Iris-setosa  8.6
# 1    4.9  3.0  1.4  0.2     Iris-setosa  7.9
# 2    4.7  3.2  1.3  0.2     Iris-setosa  7.9
# 3    4.6  3.1  1.5  0.2     Iris-setosa  7.7
# 4    5.0  3.6  1.4  0.2     Iris-setosa  8.6
# ..   ...  ...  ...  ...             ...  ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica  9.7
# 146  6.3  2.5  5.0  1.9  Iris-virginica  8.8
# 147  6.5  3.0  5.2  2.0  Iris-virginica  9.5
# 148  6.2  3.4  5.4  2.3  Iris-virginica  9.6
# 149  5.9  3.0  5.1  1.8  Iris-virginica  8.9
#
# [150 rows x 6 columns]

# %%
df1=df.groupby('spices').count()['sl']
print('df1')
# Out:
# df1

# %%
df1
# Out:
# spices
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: sl, dtype: int64

# %%
df [(df.spices =="Iris-virginica") & (df.pl > 1.5)]
# Out:
#       sl   sw   pl   pw          spices
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica
# 110  6.5  3.2  5.1  2.0  Iris-virginica
# 111  6.4  2.7  5.3  1.9  Iris-virginica
# 112  6.8  3.0  5.5  2.1  Iris-virginica
# 113  5.7  2.5  5.0  2.0  Iris-virginica
# 114  5.8  2.8  5.1  2.4  Iris-virginica
# 115  6.4  3.2  5.3  2.3  Iris-virginica
# 116  6.5  3.0  5.5  1.8  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 119  6.0  2.2  5.0  1.5  Iris-virginica
# 120  6.9  3.2  5.7  2.3  Iris-virginica
# 121  5.6  2.8  4.9  2.0  Iris-virginica
# ...
